# %%
import torch
import sys
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
sys.path.append('../scripts/src')
from multihead_admixture import AdmixtureMultiHead
import plots
import utils

# %%
trX, trY, valX, valY = utils.read_data('100K')
# Out:
# INFO:utils:Reading data...

# %%
Ks = [3,4,5,6,7,8,9,10]
num_features = trX.shape[1]
filename = 'Deep_100K_init_minibatch_kmeans_logit_K_7_bce_frac_1.0_BS_200_l2_0.1_BN_1_drpt_0.85_relu_multihead_1.pt'

# %%
device = torch.device('cuda')

# %%
model = AdmixtureMultiHead(Ks, num_features, batch_norm=True, dropout=0.85, batch_norm_hidden=False).to(device)
model.load_state_dict(torch.load(f'/home/usuaris/imatge/albert.dominguez/neural-admixture/outputs/{filename}'))
# Out:
# INFO:admixture_ae:Random decoder initialization.
# INFO:admixture_ae:Random decoder initialization.
# INFO:admixture_ae:Random decoder initialization.
# INFO:admixture_ae:Random decoder initialization.
# INFO:admixture_ae:Random decoder initialization.
# INFO:admixture_ae:Random decoder initialization.
# INFO:admixture_ae:Random decoder initialization.
# INFO:admixture_ae:Random decoder initialization.
# INFO:admixture_ae:Random decoder initialization.
# <All keys matched successfully>

# %%
plots.generate_plots(model, trX, trY, valX, valY, device, batch_size=200, k=3, is_multihead=True, min_k=3, max_k=10, to_wandb=False)
# Out:
# INFO:plots:Rendering training barplot...
# INFO:plots:Rendering validation barplot...
# INFO:plots:Done!
# 0

# %%
plots.generate_plots(model, trX, trY, valX, valY, device, batch_size=200, k=4, is_multihead=True, min_k=3, max_k=10, to_wandb=False)
# Out:
# INFO:plots:Rendering training barplot...
# INFO:plots:Rendering validation barplot...
# INFO:plots:Done!
# 0

# %%
plots.generate_plots(model, trX, trY, valX, valY, device, batch_size=200, k=5, is_multihead=True, min_k=3, max_k=10, to_wandb=False)
# Out:
# INFO:plots:Rendering training barplot...
# INFO:plots:Rendering validation barplot...
# INFO:plots:Done!
# 0

# %%
plots.generate_plots(model, trX, trY, valX, valY, device, batch_size=200, k=6, is_multihead=True, min_k=3, max_k=10, to_wandb=False)
# Out:
# INFO:plots:Rendering training barplot...
# INFO:plots:Rendering validation barplot...
# INFO:plots:Done!
# 0

# %%
plots.generate_plots(model, trX, trY, valX, valY, device, batch_size=200, k=7, is_multihead=True, min_k=3, max_k=10, to_wandb=False)
# Out:
# INFO:plots:Rendering training barplot...
# INFO:plots:Rendering validation barplot...
# INFO:plots:Done!
# 0

# %%
plots.generate_plots(model, trX, trY, valX, valY, device, batch_size=200, k=8, is_multihead=True, min_k=3, max_k=10, to_wandb=False)
# Out:
# INFO:plots:Rendering training barplot...
# INFO:plots:Rendering validation barplot...
# INFO:plots:Done!
# 0

# %%
plots.generate_plots(model, trX, trY, valX, valY, device, batch_size=200, k=9, is_multihead=True, min_k=3, max_k=10, to_wandb=False)
# Out:
# INFO:plots:Rendering training barplot...
# INFO:plots:Rendering validation barplot...
# INFO:plots:Done!
# 0

# %%
plots.generate_plots(model, trX, trY, valX, valY, device, batch_size=200, k=10, is_multihead=True, min_k=3, max_k=10, to_wandb=False)
# Out:
# INFO:plots:Rendering training barplot...
# INFO:plots:Rendering validation barplot...
# INFO:plots:Done!
# 0
